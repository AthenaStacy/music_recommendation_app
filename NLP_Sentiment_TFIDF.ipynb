# %% [markdown]
# ## Follows from NLP in NLP_Musixmatch notebook
# ### Sentiment analysis and TFIDF by decade
# ### Basic set-up for recommending by either sentiment or by lexical density (diversity)

# %%
# import things
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
# Import BeautifulSoup into your workspace
from bs4 import BeautifulSoup  
import re
import string
import operator
from __future__ import division
import datetime
#import nltk
#nltk.download()  # Download text data sets, including stop words
from nltk.corpus import stopwords # Import the stop word list
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
# Out:
# /Applications/anaconda/envs/py2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# you might need to download the "vader" stuff!
#import nltk
#nltk.download()  # Download text data sets, including stop words

# %%
#read df from pickle file
lyrics_df = pd.read_pickle('CleanedLyricsDF_MaxRank_100')
print 'lyrics_df has ', len(lyrics_df), ' songs'
print lyrics_df.head(3)
#read hot100df from pickle file
hot100_df = pd.read_pickle('./Billboard100DF_cleaned')
print 'hot100_df has ', len(hot100_df), ' songs'
# Out:
# lyrics_df has  15868  songs
#                         hot100 artist       hot100 track         track_name  \
# 0                        Ricky Nelson   Poor Little Fool   Poor Little Fool
# 2                         Bobby Darin      Splish Splash      Splish Splash
# 3  Elvis Presley With The Jordanaires  Hard Headed Woman  Hard Headed Woman
#
#                        artist_name        track_spotify_id  \
# 0                     Ricky Nelson  6kGo2CzDxnPP6pxbqABZ7l
# 2                      Bobby Darin  4RxtXFzUxQCOBAbggjN7mM
# 3  Elvis Presley & The Jordanaires
#
#                                          lyrics_body       date  \
# 0  I used to play around with hearts\nThat hasten... 1958-09-13
# 2  Splish splash, I was taking a bath\nLong about... 1958-09-06
# 3  Well a hard headed woman\nA soft hearted man\n... 1958-09-06
#
#                            lyrics_clean_no_stopwords  lex_diversity
# 0  used play around hearts hastened call met litt...       0.604167
# 2  splish splash taking bath long saturday night ...       0.868421
# 3  well hard headed woman soft hearted man cause ...       0.574468
# hot100_df has  302142  songs

# %% [markdown]
# ### Begin Sentiment Analysis (vader)

# %%
## try sentiment analysis
# We will use the vader pre-trained analyzer to classify the songs as "positive" or "negative"
# nltk.sentiment.vader.SentimentIntensityAnalyzer.polarity_scores()
import nltk.sentiment.vader as vader

# %%
res = vader.SentiText('i hate cheese')

# %%
res.words_and_emoticons
# Out:
# ['hate', 'cheese']

# %%
f = vader.SentimentIntensityAnalyzer()

# %%
f.polarity_scores('i hate cheese')
# Out:
# {'compound': -0.5719, 'neg': 0.787, 'neu': 0.213, 'pos': 0.0}

# %%
f.polarity_scores('i love cheese')
# Out:
# {'compound': 0.6369, 'neg': 0.0, 'neu': 0.192, 'pos': 0.808}

# %% [markdown]
# ### Scores make sense for loving and hating cheese. Let's try on lyrics.

# %%
subset = lyrics_df[(lyrics_df['date']>datetime.date(2010,1,1)) & (lyrics_df['date']<datetime.date(2011,1,1))]
# try it on some lyrics
for i in range(5):
    print subset[['hot100 track']].iloc[i].values, ' by ' , subset[['hot100 artist']].iloc[i].values, ' Lyrics :'
    print  subset.lyrics_clean_no_stopwords.iloc[i]
    sent_dict = f.polarity_scores(subset.lyrics_clean_no_stopwords.iloc[i])
    print 'Positive Strength = ', sent_dict['pos'], ' Negative Strength = ', sent_dict['neg']
# Out:
# ['Fearless']  by  ['Taylor Swift']  Lyrics :
# something way street looks rained glow pavement walk car know want ask dance right middle parking lot yeah drivin road wonder know trying hard get caught cool run hands hair absentmindedly makin want know gets better take hand drag headfirst fearless know dance storm best dress fearless
# Positive Strength =  0.371  Negative Strength =  0.053
# ['Imma Be']  by  ['The Black Eyed Peas']  Lyrics :
# imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma imma next level imma rockin bass treble imma chillin mutha mutha crew imma makin deals wanna hah imma list flicks doin one handed flips imma sippin trick cause imma shakin hips gon lickin lips imma takin pics lookin fly shit imma flyest chick fly imma spreadin wings imma doin thing okay imma imma swing way imma imma imma imma swing way fergie ferg imma imma stay st century til infinity imma imma imma imma imma imma imma imma imma imma rich baby quick quick imma imma imma shit baby check imma imma top never stop imma imma imma imma imma imma f ckin
# Positive Strength =  0.067  Negative Strength =  0.061
# ['Empire State Of Mind']  by  ['Jay-Z + Alicia Keys']  Lyrics :
# yea yea brooklyn tribeca right next deniro hood forever new sinatra since made make anywhere yea love everywhere used cop harlem dominicano right broadway pull back mcdonald took stashbox state st catch kitchen like simmons wippin pastry cruisin th st white lexus drivin slow bk texas bed stuy home boy biggie live billboard brought boys say whattup ty ty still sippin mai tai sittin courtside knicks nets give high five nigga spike could trip referee tell attitude definitely new york concrete jungle dreams made nothin new york streets make feel brand new big lights inspire let hear new york new york new york catch x og yankee game shit made yankee hat famous yankee know bleed blue crip though got gang niggas walkin clique though welcome melting pot corners sellin rock afrika bambataa shit home hip hop
# Positive Strength =  0.151  Negative Strength =  0.061
# ['Sexy Chick']  by  ['David Guetta Featuring Akon']  Lyrics :
# yes see cause every girl wanna oh diva feel wanna meet say low rumor believe em say needs slow baddest thing around town nothing like girl ever seen nothing compare neighborhood tryna find words describe girl without disrespectful way booty movin take stop doin pull close tryna find words describe girl without disrespectful damn girl damn sexy chick sexy chick damn sexy chick
# Positive Strength =  0.249  Negative Strength =  0.081
# ['Two Is Better Than One']  by  ['Boys Like Girls Featuring Taylor Swift']  Lyrics :
# remember wore first day came life thought hey know could something cause everything words say know takes breath away left nothing maybe true live without maybe two better one much time figure rest life already got coming undone thinking two better one
# Positive Strength =  0.0  Negative Strength =  0.155

# %% [markdown]
# ## positive scores seem pretty reasonable...
# ## let's apply to all the songs in the database:

# %%
# make functions for getting positive, negative, and compound sentiments individually
def get_pos(text):
    res = f.polarity_scores(text)
    return res['pos']
def get_neg(text):
    res = f.polarity_scores(text)
    return res['neg']
def get_compound(text):
    res = f.polarity_scores(text)
    return res['compound']

# %% [markdown]
# ## the cell below takes a couple minutes to run:

# %%
# add 3 sentiment columns to the dataframe:
lyrics_df['pos'] = lyrics_df.lyrics_clean_no_stopwords.map(get_pos)
lyrics_df['neg'] = lyrics_df.lyrics_clean_no_stopwords.map(get_neg)
lyrics_df['compound_sentiment'] = lyrics_df.lyrics_clean_no_stopwords.map(get_compound)

# %%
lyrics_df[['compound_sentiment']].iloc[0].values[0]
# Out:
# -0.9597

# %%
## plot positive sentiment as a funciton of time
matplotlib.rcParams.update({'font.size': 22})
# what if look at a smoothed time series
#(want to take annual averages as well, but this is easy)
def window(size):
    return np.ones(size)/float(size)
times = lyrics_df.sort_values('date').date.values
vals = lyrics_df.sort_values('date').pos.values
plt.plot(times,vals,'k.')
plt.plot(times,np.convolve(vals,window(10),'same'),'r')
plt.plot(times,np.convolve(vals,window(100),'same'),'b')

plt.ylabel('Positivity')
fig = plt.gcf()
fig.set_size_inches(15.5, 8.5)
plt.title('Positivity v Time')

plt.savefig('Positivity')

# %%
## plot positive sentiment as a funciton of time
matplotlib.rcParams.update({'font.size': 22})
# what if look at a smoothed time series
#(want to take annual averages as well, but this is easy)
def window(size):
    return np.ones(size)/float(size)
times = lyrics_df.sort_values('date').date.values
vals = lyrics_df.sort_values('date').neg.values
plt.plot(times,vals,'k.')
plt.plot(times,np.convolve(vals,window(10),'same'),'r')
plt.plot(times,np.convolve(vals,window(100),'same'),'b')

plt.ylabel('Negativity')
fig = plt.gcf()
fig.set_size_inches(15.5, 8.5)
plt.title('Negativity v Time')
plt.savefig('Negativity')

# %%
## plot positive sentiment as a funciton of time
matplotlib.rcParams.update({'font.size': 22})
# what if look at a smoothed time series
#(want to take annual averages as well, but this is easy)
def window(size):
    return np.ones(size)/float(size)
times = lyrics_df.sort_values('date').date.values
vals = lyrics_df.sort_values('date').compound_sentiment.values
plt.plot(times,vals,'k.')
plt.plot(times,np.convolve(vals,window(10),'same'),'r')
plt.plot(times,np.convolve(vals,window(100),'same'),'b')

plt.ylabel('Compound Sentiment')
fig = plt.gcf()
fig.set_size_inches(15.5, 8.5)
plt.title('Compound Sentiment v Time')

# %% [markdown]
# ### you could imagine building a recommender that uses just the criteria of lexical density or positivity, filters for more recent years, sorts by similarity of criteria, and says "you might like this more recent track":

# %% [markdown]
# ## Simple Recommender! (Using lex_diversity only)

# %% [markdown]
# ## The first step in the recommender will be to search the database for a user input of a song they like. Probably want to have the user input an artist too, in case there are multiple song title matches (for example, "The Sound of Silence" in the cell below gets 3 results
# ##  First search for exact matches, then do something like convert everything to lowercase and do a fuzzy match? A start is below, but the simplest thing for now is to just choose song titles that get exactly one matching song, such as:
# >## Bohemian Rhapsody
# >## Semi-Charmed Life
# >## Creep
# >## Lose Yourself

# %%
# here you can test if your song is in the database
#Example songs that are here: 'Bohemian Rhapsody', 'Creep','Semi-Charmed Life', 'Fearless', 'Lose Yourself'
song_i_like = 'The Sound of Silence' #oh no! this one has 3 matches, so you might want to add:
artist_i_like = 'Simon & Garfunkel'
#match == rows of lyrics_df matching your query
match = lyrics_df[lyrics_df['track_name']==song_i_like]
if len(match)==1:
    print 'Found 1 matching song!'
    print match[['hot100 track']].values, ' by ', match[['hot100 artist']].values
if len(match)==0:
    print 'No matching song! Try again.'
if len(match)>1:
    # use artist as well
    match = match[match['hot100 artist']==artist_i_like]
    print 'Found 1 matching song!'
    print match[['hot100 track']].values, ' by ', match[['hot100 artist']].values
# Out:
# Found 1 matching song!
# [['The Sound Of Silence']]  by  [['Simon & Garfunkel']]

# %%
#recommend a song based on lexical density only
song_i_like = 'Creep'

#define similarity as diff between your song's lexical diversity & that of other songs
lex = lyrics_df[lyrics_df['track_name']==song_i_like].lex_diversity.values[0]
lyrics_df['dist'] = lyrics_df.lex_diversity.map((lambda x: abs(lex - x)))

#there will be some songs with identical lexical diversity to your song
print 'exact matches = ', len(lyrics_df[lyrics_df['dist']==0])

#recommend 5 songs based on lexical diversity
print 'You might like these recent tracks:'
lyrics_df[lyrics_df['date']>datetime.date(2013,1,1)].sort_values('dist')[:5]
# Out:
# exact matches =  52
# You might like these recent tracks:
#     hot100 artist   hot100 track     track_name   artist_name  \
# 244        Avicii    Wake Me Up!     Wake Me Up        Avicci
# 148    Luke Bryan  Play It Again  Play It Again    Luke Bryan
# 360   Jana Kramer  I Got The Boy  I Got the Boy   Jana Kramer
# 346         Adele          Hello          Hello         Adele
# 116  Randy Houser        We Went        We Went  Randy Houser
#
#            track_spotify_id  \
# 244
# 148  03fT3OHB9KyMtGMt2zwqCT
# 360  6tbNaE7kvGNqS7FvJ0dzLB
# 346  193O4vZOZvdx7vrfZpfs37
# 116  1wrZNOmdzrg0QZTvKSBZm3
#
#                                            lyrics_body       date  \
# 244  Feeling my way through the darkness\nGuided by... 2014-01-11
# 148  She was sittin' all alone over on the tailgate... 2014-06-07
# 360  I saw your picture in a paper, Honeymoon in Ja... 2015-12-26
# 346  Hello,\nit's me\nI was wondering if after all ... 2016-02-13
# 116  Black pontiac with a pocket of cash\nFoot on t... 2016-02-20
#
#                              lyrics_clean_no_stopwords  lex_diversity    pos  \
# 244  feeling way darkness guided beating heart tell...       0.903226  0.285
# 148  sittin alone tailgate tan legs swingin georgia...       0.903226  0.308
# 360  saw picture paper honeymoon jamaica lucky girl...       0.906977  0.357
# 346  hello wondering years like meet go everything ...       0.902439  0.126
# 116  black pontiac pocket cash foot gas ready throw...       0.901961  0.124
#
#        neg  compound_sentiment      dist
# 244  0.178              0.3400  0.001536
# 148  0.052              0.9607  0.001536
# 360  0.028              0.9565  0.002215
# 346  0.070              0.5574  0.002323
# 116  0.037              0.5918  0.002801

# %% [markdown]
# ## The following few cells use lexical density criterion only to recommend "recent" songs:

# %%
#recommend a song based on lexical density only
song_i_like = 'Semi-Charmed Life'

#define similarity as diff between your song's lexical diversity & that of other songs
lex = lyrics_df[lyrics_df['track_name']==song_i_like].lex_diversity.values[0]
lyrics_df['dist'] = lyrics_df.lex_diversity.map((lambda x: abs(lex - x)))

#there will be some songs with identical lexical diversity to your song
print 'exact matches = ', len(lyrics_df[lyrics_df['dist']==0])

#recommend 5 songs based on lexical diversity
print 'You might like these recent tracks:'
lyrics_df[lyrics_df['date']>datetime.date(2013,1,1)].sort_values('dist')[:5]
# Out:
# exact matches =  4
# You might like these recent tracks:
#                   hot100 artist              hot100 track  \
# 268                       Drake              Back To Back
# 111           Empire Of The Sun        Walking On A Dream
# 193                      MAGIC!                      Rude
# 194            Kelsea Ballerini  Love Me Like You Mean It
# 149  Future Featuring Lil Wayne       Karate Chop (Remix)
#
#                    track_name         artist_name        track_spotify_id  \
# 268              Back To Back               Drake  4rujbg8RNFitwtkv1qEq4K
# 111        Walking On a Dream   Empire of the Sun  0mBkoM8r7KAQzZij5swTUL
# 193                      Rude              MAGIC!  3tCwjWLicbjsMCvXhN0WOE
# 194  Love Me Like You Mean It    Kelsea Ballerini  0knbW9EwgSLfNFMWys1mQm
# 149       Karate Chop (remix)  Future & Lil Wayne
#
#                                            lyrics_body       date  \
# 268  Oh man, oh man, oh man\n\nNot again\nYeah, I l... 2015-10-31
# 111  Walking on a dream\nHow can I explain\nTalking... 2016-02-20
# 193  Saturday morning, jumped out of bed\nAnd put o... 2014-09-27
# 194  hey, boy with your hat back mmm i kinda like t... 2015-06-20
# 149  You know, This just some real nigga shit, a re... 2013-05-04
#
#                              lyrics_clean_no_stopwords  lex_diversity    pos  \
# 268  oh man oh man oh man yeah learned game william...       0.734940  0.151
# 111  walking dream explain talking see always runni...       0.735294  0.227
# 193  saturday morning jumped bed put best suit got ...       0.735294  0.307
# 194  hey boy hat back mmm kinda like wanna walk way...       0.734375  0.411
# 149  know real nigga shit real nigga story know say...       0.736364  0.073
#
#        neg  compound_sentiment      dist
# 268  0.188             -0.7096  0.000000
# 111  0.080              0.6288  0.000354
# 193  0.147              0.9212  0.000354
# 194  0.084              0.9806  0.000565
# 149  0.091             -0.6369  0.001424

# %%
#recommend a song based on lexical density only
song_i_like = 'Bohemian Rhapsody'

#define similarity as diff between your song's lexical diversity & that of other songs
lex = lyrics_df[lyrics_df['track_name']==song_i_like].lex_diversity.values[0]
lyrics_df['dist'] = lyrics_df.lex_diversity.map((lambda x: abs(lex - x)))

#there will be some songs with identical lexical diversity to your song
print 'exact matches = ', len(lyrics_df[lyrics_df['dist']==0])

#recommend 5 songs based on lexical diversity
print 'You might like these recent tracks:'
lyrics_df[lyrics_df['date']>datetime.date(2013,1,1)].sort_values('dist')[:5]
# Out:
# exact matches =  6
# You might like these recent tracks:
#                                          hot100 artist  \
# 151                        Young Money Featuring Drake
# 377                  Hunter Hayes Featuring Jason Mraz
# 310                   Kendrick Lamar Featuring MC Eiht
# 241  Brantley Gilbert Featuring Justin Moore & Thom...
# 163                                     The Band Perry
#
#                         hot100 track                       track_name  \
# 151                         Trophies                         Trophies
# 377  Everybody's Got Somebody But Me  Everybody's Got Somebody But Me
# 310                     m.A.A.d City                     m.A.A.d city
# 241             Small Town Throwdown             Small Town Throwdown
# 163                            DONE.                            Done.
#
#                                            artist_name  \
# 151                            Young Money feat. Drake
# 377                      Hunter Hayes feat. Jason Mraz
# 310                       Kendrick Lamar feat. MC Eiht
# 241  Brantley Gilbert feat. Justin Moore & Thomas R...
# 163                                     The Band Perry
#
#            track_spotify_id  \
# 151  0zCiXVyOOAlLrW84uBpGRx
# 377
# 310  0nfQguNoAfKFjsQHr6qnxc
# 241  0rX4YStqUt1k1VEBe1U4HJ
# 163  5w8Btq3MrCnXiN0QtmFMf8
#
#                                            lyrics_body       date  \
# 151  Had hit records on my demo\nDid y'all boys not... 2014-05-31
# 377  I wish the couple on the corner would just get... 2013-12-21
# 310  If Pirus and Crips all got along\nThey'd proba... 2013-09-21
# 241  Aw son\n\nAround these parts ain't much to do\... 2014-09-06
# 163  You've been wearing that crown and tearing me ... 2013-06-08
#
#                              lyrics_clean_no_stopwords  lex_diversity    pos  \
# 151  hit records demo boys get memo stay interconti...       0.859649  0.217
# 377  wish couple corner would get room seems like e...       0.860000  0.273
# 310  pirus crips got along probably gun end song se...       0.861878  0.121
# 241  aw son around parts much except work like dog ...       0.862069  0.154
# 163  wearing crown tearing since treated right stru...       0.862069  0.191
#
#        neg  compound_sentiment      dist
# 151  0.215             -0.4236  0.000000
# 377  0.084              0.9189  0.000351
# 310  0.289             -0.9928  0.002229
# 241  0.064              0.6240  0.002420
# 163  0.070              0.8118  0.002420

# %%
#recommend a song based on lexical density only
song_i_like = 'Lose Yourself'

#define similarity as diff between your song's lexical diversity & that of other songs
lex = lyrics_df[lyrics_df['track_name']==song_i_like].lex_diversity.values[0]
lyrics_df['dist'] = lyrics_df.lex_diversity.map((lambda x: abs(lex - x)))

#there will be some songs with identical lexical diversity to your song
print 'exact matches = ', len(lyrics_df[lyrics_df['dist']==0])

#recommend 5 songs based on lexical diversity
print 'You might like these recent tracks:'
lyrics_df[lyrics_df['date']>datetime.date(2013,1,1)].sort_values('dist')[:5]
# Out:
# exact matches =  1
# You might like these recent tracks:
#                                  hot100 artist    hot100 track  \
# 259                                  Echosmith       Cool Kids
# 126                                 Trey Songz     Slow Motion
# 204                                       P!nk  Just Like Fire
# 197                                        Sia      Chandelier
# 276  Big Sean Featuring Lil Wayne & Jhene Aiko          Beware
#
#          track_name                            artist_name  \
# 259       Cool Kids                              Echosmith
# 126     Slow Motion                             Trey Songz
# 204  Just Like Fire                                   P!nk
# 197      Chandelier                                    Sia
# 276          Beware  Big Sean feat. Lil Wayne & Jhené Aiko
#
#            track_spotify_id  \
# 259  13P5rwmk2EsoFRIz9UCeh9
# 126  6LRLA7j6uPetzUzBIMAHQE
# 204  3AmiKNhylTZGpEXIm5AepY
# 197  3D4QFgYa3P9P0gjmv4eX6I
# 276  2VxlGxgtXBZViTR92zAwhV
#
#                                            lyrics_body       date  \
# 259  She says, "I'm walkin' in a straight line"\nTh... 2014-10-11
# 126  I know you got all dressed up for the club,\nW... 2015-05-30
# 204  I know that I'm running out of time\nI want it... 2016-06-11
# 197  Party girls don't get hurt\nCan't feel anythin... 2014-11-01
# 276  When you said it was over\nYou shot right thro... 2013-10-19
#
#                              lyrics_clean_no_stopwords  lex_diversity    pos  \
# 259  says walkin straight line really style got hea...       0.680851  0.560
# 126  know got dressed club waiting come pick baby s...       0.680851  0.039
# 204  know running time want mmm mmm wishing stop tr...       0.681319  0.303
# 197  party girls get hurt feel anything learn push ...       0.679245  0.297
# 276  said shot right heart let hoes tear right apar...       0.681416  0.138
#
#        neg  compound_sentiment      dist
# 259  0.000              0.9867  0.000523
# 126  0.039              0.0000  0.000523
# 204  0.126              0.9468  0.000991
# 197  0.110              0.9260  0.001083
# 276  0.185             -0.7716  0.001088

# %% [markdown]
# ## Recommender using compound_sentiment only:

# %%
#recommend a song based on compound_sentiment only
song_i_like = 'Creep' #enter a song you like

#define similarity as diff between your song's sentiment and that of other songs
comp = lyrics_df[lyrics_df['track_name']==song_i_like].compound_sentiment.values[0]
lyrics_df['dist2'] = lyrics_df.compound_sentiment.map((lambda x: abs(comp - x)))

#recommend 5 songs based on compound sentiment
print 'exact matches = ', len(lyrics_df[lyrics_df['dist2']==0])
print 'You might like these recent tracks:'
lyrics_df[lyrics_df['date']>datetime.date(2013,1,1)].sort_values('dist2')[:5]
# Out:
# exact matches =  88
# You might like these recent tracks:
#                                  hot100 artist           hot100 track  \
# 357                              One Direction                   Home
# 382  Missy Elliott Featuring Pharrell Williams  WTF (Where They From)
# 206                            Rich Homie Quan     Flex (Ooh Ooh Ooh)
# 183                           Carrie Underwood        Little Toy Guns
# 358          Travie McCoy Featuring Jason Mraz            Rough Water
#
#                 track_name                            artist_name  \
# 357                   Home                          One Direction
# 382  WTF (Where They From)  Missy Elliott feat. Pharrell Williams
# 206   Flex (Ooh, Ooh, Ooh)                        Rich Homie Quan
# 183        Little Toy Guns                       Carrie Underwood
# 358            Rough Water          Travie McCoy feat. Jason Mraz
#
#            track_spotify_id  \
# 357  0uZzdkuzJEjFzaRR2HQ5mj
# 382
# 206  2LLFl56eIFGFlnrplUC26f
# 183  4lnnde7PnrXR3pUzQKBe6X
# 358
#
#                                            lyrics_body       date  \
# 357  Make a little conversation\nSo long, I've been... 2015-11-14
# 382  The dance you doing is dumb\nHow they do where... 2016-01-16
# 206  Aye, oh, there it is, there it is, there it is... 2015-08-08
# 183  "Little Toy Guns"\n\nIn between the coats in t... 2015-06-06
# 358  Hey oh, never let go of me (Never let go)\nHol... 2013-11-23
#
#                              lyrics_clean_no_stopwords  lex_diversity    pos  \
# 357  make little conversation long waiting let go f...       0.925000  0.216
# 382  dance dumb stickin tongue girl know young bunc...       0.697248  0.171
# 206  aye oh rich homie baby walked pocket niggas li...       0.674419  0.211
# 183  little toy guns coats closet held heart shaped...       0.830508  0.260
# 358  hey oh never let go never let go hold tight go...       0.590476  0.129
#
#        neg  compound_sentiment      dist   dist2
# 357  0.126              0.6705  0.244672  0.0000
# 382  0.138              0.6705  0.016920  0.0000
# 206  0.142              0.6705  0.005909  0.0000
# 183  0.205              0.6743  0.150181  0.0038
# 358  0.108              0.6664  0.089852  0.0041

# %%
#recommend a song based on compound_sentiment only
song_i_like = 'Bohemian Rhapsody' #enter a song you like

#define similarity as diff between your song's sentiment and that of other songs
comp = lyrics_df[lyrics_df['track_name']==song_i_like].compound_sentiment.values[0]
lyrics_df['dist2'] = lyrics_df.compound_sentiment.map((lambda x: abs(comp - x)))

#recommend 5 songs based on compound sentiment
print 'exact matches = ', len(lyrics_df[lyrics_df['dist2']==0])
print 'You might like these recent tracks:'
lyrics_df[lyrics_df['date']>datetime.date(2013,1,1)].sort_values('dist2')[:5]
# Out:
# exact matches =  1
# You might like these recent tracks:
#                          hot100 artist        hot100 track  \
# 182                        Nico & Vinz          Am I Wrong
# 51                            Yo Gotti      Down In The DM
# 110  Hoodie Allen Featuring Ed Sheeran        All About It
# 178                            T-Wayne     Nasty Freestyle
# 116      A$AP Rocky Featuring Skrillex  Wild For The Night
#
#              track_name                    artist_name  \
# 182          Am I Wrong                    Nico & Vinz
# 51       Down In the DM                       Yo Gotti
# 110        All About It  Hoodie Allen feat. Ed Sheeran
# 178     Nasty Freestyle                        T-Wayne
# 116  Wild for the Night      A$AP Rocky feat. Skrillex
#
#            track_spotify_id  \
# 182  08SxltHeEkQqgx5foDRRqO
# 51   54KbpaNkWhOLwonw3lhwxY
# 110  58hb0g5ctZ2XyZyvbZM2n2
# 178
# 116
#
#                                            lyrics_body       date  \
# 182  Am I wrong\nFor thinking out the box from wher... 2014-08-16
# 51   I see your girl post her bm, so I hit her in h... 2016-01-23
# 110  Cause I got soul and I won't quit\nAnd your da... 2015-02-07
# 178  First let me hop out motherfucking Porsche\nI ... 2015-07-11
# 116  Wake up falling blessed up, pistol on that dre... 2013-05-25
#
#                              lyrics_clean_no_stopwords  lex_diversity    pos  \
# 182  wrong thinking box stay wrong saying choose an...       0.723404  0.105
# 51   see girl post bm hit dm eyes yeah see em yeah ...       0.603448  0.093
# 110  cause got soul quit dad like talk shit cause b...       0.865169  0.156
# 178  first let hop motherfucking porsche want ass s...       0.909091  0.174
# 116  wake falling blessed pistol dresser afraid sho...       0.771186  0.196
#
#        neg  compound_sentiment      dist   dist2
# 182  0.216             -0.8555  0.043076  0.0008
# 51   0.197             -0.8591  0.076880  0.0028
# 110  0.236             -0.8591  0.184841  0.0028
# 178  0.260             -0.8591  0.228763  0.0028
# 116  0.248             -0.8500  0.090859  0.0063

# %% [markdown]
# ## Baggin' and TFIDF'n
#
# ## First just by decade to see if any interesting features pop up

# %%
#if we want to do tf-idf to see what words are unique in particular decades, we need to make a new
# dataframe with only 50 60 70 80 90 00 10 (7 rows, one for each decade), and all the lyrics from that decade in
# each row
decades_lyrics = []
y = 1950
decades = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
for y in decades:
#    print y, '\'s'
    start_date = datetime.date(year=y,month=1,day=1)
    end_date = datetime.date(year=y+10,month=1,day=1)
    subset = lyrics_df[(lyrics_df['date'] > start_date) & (lyrics_df['date'] < end_date) ]
    lyrics = subset.lyrics_clean_no_stopwords
    lyrics = string.join(lyrics) #join all the words into one string
    decades_lyrics.append(lyrics)

# %%
len(decades_lyrics)
#decades_lyrics[0]
# Out:
# 7

# %% [markdown]
# ## The cell below takes a minute to run! (Makes BoW feature arrays for documents = all lyrics per decade)

# %%
# make bag-of-words arrays for each decade, both raw and tfidf-weighted
transformer = TfidfTransformer() #to do tfidf weighting on all of the bag_of_words vectors

all3_vec = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000, \
                             ngram_range=(1,3)) 
all3_features = all3_vec.fit_transform(decades_lyrics)
tfidf_all3 = transformer.fit_transform(all3_features)
all3_features = all3_features.toarray()
tfidf_all3 = tfidf_all3.toarray()

bigram_vec = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000, \
                             ngram_range=(2,2))
bigram_features = bigram_vec.fit_transform(decades_lyrics)
tfidf_bigram = transformer.fit_transform(bigram_features)
bigram_features = bigram_features.toarray()
tfidf_bigram = tfidf_bigram.toarray()

trigram_vec = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000, \
                             ngram_range=(3,3)) 
trigram_features = trigram_vec.fit_transform(decades_lyrics)
tfidf_trigram = transformer.fit_transform(trigram_features)
trigram_features = trigram_features.toarray()
tfidf_trigram = tfidf_trigram.toarray()

# %%
np.shape(all3_features)
# Out:
# (7, 5000)

# %%
# get the overall common features in our corpus
n=20
#all3
vocab = all3_vec.get_feature_names()
word_features = all3_features
# Sum up the counts of each vocabulary word
dist = np.sum(word_features, axis=0)
count_dict = dict(zip(vocab, dist))
#sort dict by counts to see most frequent words
sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
#look at just the top 50 most frequent features
print n, ' most frequent features (all3):'
print sorted_count_dict[:n]
top_20_overall = sorted_count_dict[:20]
#bigram
vocab = bigram_vec.get_feature_names()
word_features = bigram_features
# Sum up the counts of each vocabulary word
dist = np.sum(word_features, axis=0)
count_dict = dict(zip(vocab, dist))
#sort dict by counts to see most frequent words
sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
#look at just the top 50 most frequent features
print n, ' most frequent features (bigram):'
print sorted_count_dict[:n]
top_20_overall_bigram = sorted_count_dict[:20]
#trigram
vocab = trigram_vec.get_feature_names()
word_features = trigram_features
# Sum up the counts of each vocabulary word
dist = np.sum(word_features, axis=0)
count_dict = dict(zip(vocab, dist))
#sort dict by counts to see most frequent words
sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
#look at just the top 50 most frequent features
print n, ' most frequent features (trigram):'
print sorted_count_dict[:n]
top_20_overall_trigram = sorted_count_dict[:20]
# Out:
# 20  most frequent features (all3):
# [(u'love', 13429), (u'know', 10302), (u'like', 9819), (u'got', 8329), (u'oh', 8227), (u'baby', 7740), (u'get', 7434), (u'yeah', 6261), (u'one', 5629), (u'go', 5540), (u'let', 5496), (u'time', 5299), (u'see', 4864), (u'never', 4809), (u'girl', 4673), (u'make', 4630), (u'say', 4611), (u'want', 4497), (u'come', 4489), (u'way', 4483)]
# 20  most frequent features (bigram):
# [(u'oh oh', 2145), (u'yeah yeah', 1472), (u'la la', 1469), (u'na na', 963), (u'let go', 810), (u'love love', 772), (u'hey hey', 677), (u'ooh ooh', 654), (u'oh yeah', 640), (u'da da', 535), (u'baby baby', 454), (u'know know', 454), (u'feel like', 437), (u'doo doo', 429), (u'get get', 423), (u'every time', 390), (u'oh baby', 388), (u'ah ah', 386), (u'every day', 354), (u'know love', 352)]
# 20  most frequent features (trigram):
# [(u'oh oh oh', 1185), (u'la la la', 1182), (u'na na na', 787), (u'yeah yeah yeah', 738), (u'ooh ooh ooh', 399), (u'da da da', 367), (u'doo doo doo', 312), (u'hey hey hey', 304), (u'love love love', 242), (u'ah ah ah', 238), (u'get get get', 190), (u'ha ha ha', 181), (u'baby baby baby', 123), (u'know know know', 117), (u'ba ba ba', 115), (u'yeah oh yeah', 104), (u'come come come', 104), (u'whoa whoa whoa', 89), (u'oh yeah oh', 89), (u'let go let', 87)]

# %% [markdown]
# ### convert dicts to lists of top 20 features, we'll use these lists later to filter words common to all decades (to let more decade-specific words come through

# %%
top_20_overall = [str(i[0]) for i in top_20_overall]
top_20_overall_bigram = [str(i[0]) for i in top_20_overall_bigram]
top_20_overall_trigram = [str(i[0]) for i in top_20_overall_trigram]

# %% [markdown]
# ## Most common unigrams (+2 +3-grams) (Raw Counts) (By Decade)

# %%
n=20
for i in range(len(decades)):
    print str(decades[i])+'\'s'
    vocab = all3_vec.get_feature_names()
    dist = all3_features[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    print n, ' most frequent features:'
    print sorted_count_dict[:n]
# Out:
# 1950's
# 20  most frequent features:
# [(u'love', 305), (u'oh', 215), (u'baby', 131), (u'know', 117), (u'got', 107), (u'never', 101), (u'well', 100), (u'like', 96), (u'little', 94), (u'come', 93), (u'girl', 87), (u'say', 85), (u'yeah', 84), (u'gonna', 82), (u'way', 79), (u'one', 77), (u'heart', 77), (u'pretty', 76), (u'time', 74), (u'la', 74)]
# 1960's
# 20  most frequent features:
# [(u'love', 2797), (u'baby', 1562), (u'oh', 1513), (u'know', 1377), (u'got', 1089), (u'yeah', 1062), (u'like', 942), (u'one', 866), (u'little', 851), (u'come', 829), (u'girl', 820), (u'go', 809), (u'let', 774), (u'see', 761), (u'time', 759), (u'get', 742), (u'say', 738), (u'heart', 706), (u'never', 676), (u'way', 645)]
# 1970's
# 20  most frequent features:
# [(u'love', 2629), (u'know', 1493), (u'oh', 1395), (u'baby', 1392), (u'got', 1351), (u'get', 1184), (u'like', 1141), (u'time', 935), (u'let', 909), (u'yeah', 881), (u'come', 841), (u'one', 821), (u'way', 798), (u'gonna', 780), (u'go', 769), (u'make', 745), (u'never', 722), (u'say', 718), (u'see', 709), (u'man', 653)]
# 1980's
# 20  most frequent features:
# [(u'love', 2651), (u'know', 1631), (u'oh', 1400), (u'like', 1217), (u'got', 1192), (u'baby', 1139), (u'time', 1040), (u'one', 991), (u'get', 964), (u'never', 849), (u'say', 817), (u'want', 791), (u'yeah', 786), (u'go', 786), (u'let', 783), (u'night', 743), (u'heart', 743), (u'see', 741), (u'make', 707), (u'feel', 703)]
# 1990's
# 20  most frequent features:
# [(u'love', 2163), (u'know', 1807), (u'like', 1775), (u'get', 1418), (u'baby', 1322), (u'got', 1279), (u'yeah', 1076), (u'oh', 1037), (u'one', 1033), (u'time', 984), (u'let', 973), (u'want', 920), (u'never', 919), (u'go', 863), (u'make', 851), (u'come', 845), (u'see', 843), (u'cause', 818), (u'say', 817), (u'wanna', 801)]
# 2000's
# 20  most frequent features:
# [(u'like', 2538), (u'know', 2328), (u'get', 1999), (u'got', 1777), (u'love', 1662), (u'go', 1302), (u'yeah', 1287), (u'oh', 1271), (u'baby', 1198), (u'girl', 1186), (u'let', 1178), (u'see', 1155), (u'one', 1138), (u'wanna', 1067), (u'cause', 1014), (u'make', 1002), (u'back', 984), (u'time', 937), (u'way', 903), (u'want', 891)]
# 2010's
# 20  most frequent features:
# [(u'like', 2110), (u'know', 1549), (u'got', 1534), (u'oh', 1396), (u'love', 1222), (u'yeah', 1085), (u'get', 1062), (u'baby', 996), (u'go', 943), (u'let', 823), (u'make', 726), (u'cause', 723), (u'one', 703), (u'wanna', 702), (u'back', 701), (u'girl', 697), (u'want', 675), (u'never', 673), (u'oh oh', 593), (u'see', 586)]

# %% [markdown]
# ## Most common bigrams (Raw Counts) (By Decade)

# %%
n=12
for i in range(len(decades)):
    print str(decades[i])+'\'s'
    vocab = bigram_vec.get_feature_names()
    dist = bigram_features[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    print n, ' most frequent features:'
    print sorted_count_dict[:n]
# Out:
# 1950's
# 12  most frequent features:
# [(u'oh oh', 63), (u'na na', 56), (u'la la', 55), (u'da da', 38), (u'yeah yeah', 37), (u'cha cha', 36), (u'love love', 29), (u'pretty girl', 27), (u'ooh ooh', 26), (u'bom bom', 23), (u'hey hey', 22), (u'ah ah', 20)]
# 1960's
# 12  most frequent features:
# [(u'yeah yeah', 359), (u'la la', 344), (u'oh oh', 292), (u'love love', 162), (u'oh yeah', 154), (u'hey hey', 139), (u'little girl', 121), (u'da da', 104), (u'ba ba', 102), (u'oop oop', 102), (u'ah ah', 101), (u'ooh ooh', 99)]
# 1970's
# 12  most frequent features:
# [(u'la la', 254), (u'yeah yeah', 207), (u'doo doo', 196), (u'oh oh', 190), (u'ooh ooh', 170), (u'love love', 168), (u'hey hey', 120), (u'oh yeah', 118), (u'get get', 116), (u'oh baby', 97), (u'baby baby', 95), (u'rock roll', 93)]
# 1980's
# 12  most frequent features:
# [(u'oh oh', 319), (u'yeah yeah', 213), (u'let go', 157), (u'ooh ooh', 156), (u'love love', 110), (u'na na', 109), (u'oh yeah', 80), (u'oh baby', 77), (u'know love', 75), (u'every time', 68), (u'baby baby', 65), (u'feel like', 62)]
# 1990's
# 12  most frequent features:
# [(u'oh oh', 284), (u'yeah yeah', 215), (u'la la', 124), (u'let go', 123), (u'da da', 112), (u'oh yeah', 111), (u'baby baby', 106), (u'ooh ooh', 106), (u'na na', 105), (u'know know', 88), (u'uh huh', 85), (u'get get', 84)]
# 2000's
# 12  most frequent features:
# [(u'la la', 413), (u'oh oh', 404), (u'na na', 294), (u'yeah yeah', 251), (u'let go', 209), (u'da da', 181), (u'hey hey', 142), (u'uh uh', 135), (u'love love', 127), (u'ha ha', 125), (u'get get', 120), (u'let get', 111)]
# 2010's
# 12  most frequent features:
# [(u'oh oh', 593), (u'na na', 255), (u'la la', 231), (u'yeah yeah', 190), (u'let go', 151), (u'hey hey', 135), (u'know know', 104), (u'feel like', 102), (u'work work', 95), (u'love love', 95), (u'oh yeah', 79), (u'like like', 63)]

# %% [markdown]
# ## Most common tri-grams (Raw Counts) (By Decade)

# %%
n=12
for i in range(len(decades)):
    print str(decades[i])+'\'s'
    vocab = trigram_vec.get_feature_names()
    dist = trigram_features[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    print n, ' most frequent features:'
    print sorted_count_dict[:n]
# Out:
# 1950's
# 12  most frequent features:
# [(u'na na na', 53), (u'la la la', 50), (u'da da da', 34), (u'oh oh oh', 30), (u'cha cha cha', 22), (u'yeah yeah yeah', 21), (u'bom bom bom', 19), (u'ooh ooh ooh', 19), (u'dooby doom dooby', 16), (u'pretty girl pretty', 15), (u'ah ah ah', 13), (u'girl pretty girl', 12)]
# 1960's
# 12  most frequent features:
# [(u'la la la', 270), (u'yeah yeah yeah', 203), (u'oh oh oh', 139), (u'ah ah ah', 77), (u'da da da', 76), (u'oop oop oop', 76), (u'ba ba ba', 75), (u'ooh ooh ooh', 63), (u'na na na', 63), (u'hey hey hey', 60), (u'batman batman batman', 57), (u'doo doo doo', 54)]
# 1970's
# 12  most frequent features:
# [(u'la la la', 197), (u'doo doo doo', 152), (u'ooh ooh ooh', 112), (u'yeah yeah yeah', 93), (u'oh oh oh', 73), (u'get get get', 61), (u'love love love', 47), (u'na na na', 47), (u'ah ah ah', 45), (u'hey hey hey', 42), (u'oo oo oo', 37), (u'nah nah nah', 33)]
# 1980's
# 12  most frequent features:
# [(u'oh oh oh', 159), (u'yeah yeah yeah', 118), (u'na na na', 93), (u'ooh ooh ooh', 83), (u'love love love', 30), (u'ha ha ha', 27), (u'doo doo doo', 27), (u'whoa whoa whoa', 26), (u'la la la', 26), (u'ba ba ba', 23), (u'baby baby baby', 23), (u'hot hot hot', 21)]
# 1990's
# 12  most frequent features:
# [(u'oh oh oh', 186), (u'yeah yeah yeah', 99), (u'la la la', 98), (u'na na na', 83), (u'ooh ooh ooh', 76), (u'da da da', 64), (u'baby baby baby', 45), (u'around world around', 43), (u'world around world', 43), (u'doo doo doo', 34), (u'check check check', 33), (u'yes yes yes', 32)]
# 2000's
# 12  most frequent features:
# [(u'la la la', 370), (u'na na na', 253), (u'oh oh oh', 227), (u'da da da', 131), (u'yeah yeah yeah', 109), (u'ha ha ha', 81), (u'hey hey hey', 75), (u'uh uh uh', 62), (u'wee ooh wee', 60), (u'love love love', 59), (u'get get get', 59), (u'oh uh oh', 39)]
# 2010's
# 12  most frequent features:
# [(u'oh oh oh', 371), (u'na na na', 195), (u'la la la', 171), (u'yeah yeah yeah', 95), (u'hey hey hey', 80), (u'work work work', 66), (u'know know know', 43), (u'eh eh eh', 38), (u'imma imma imma', 38), (u'clique clique clique', 36), (u'ooh ooh ooh', 33), (u'love love love', 30)]

# %% [markdown]
# ## Interesting thing to do for visualization: Plot time series of certain words (maybe get frequencies of words annually instead of decadally, and plot as time series, like google trends). You'll see the arrival of explicit words in popular music + maybe other interesting things, like love becoming less ubiquitous.

# %% [markdown]
# ## TFIDF

# %% [markdown]
# ### TFIDF all 3 (uni+ 2- + 3-grams)

# %%
# tfidf now...
n=10
for i in range(len(decades)):
    vocab = all3_vec.get_feature_names()
    print str(decades[i])+'\'s'
    dist = tfidf_all3[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    #print n, ' most frequent features:'
    #print sorted_count_dict[:n]
    word, freq = zip(*sorted_count_dict)
    print str(decades[i])+'\'s', map(lambda x: x.encode('ascii'), word[0:10])
# Out:
# 1950's
# 1950's ['love', 'oh', 'baby', 'know', 'got', 'never', 'well', 'like', 'little', 'come']
# 1960's
# 1960's ['love', 'baby', 'oh', 'know', 'got', 'yeah', 'like', 'one', 'little', 'come']
# 1970's
# 1970's ['love', 'know', 'oh', 'baby', 'got', 'get', 'like', 'time', 'let', 'yeah']
# 1980's
# 1980's ['love', 'know', 'oh', 'like', 'got', 'baby', 'time', 'one', 'get', 'never']
# 1990's
# 1990's ['love', 'know', 'like', 'get', 'baby', 'got', 'yeah', 'oh', 'one', 'time']
# 2000's
# 2000's ['like', 'know', 'get', 'got', 'love', 'go', 'yeah', 'oh', 'baby', 'girl']
# 2010's
# 2010's ['like', 'know', 'got', 'oh', 'love', 'yeah', 'get', 'baby', 'go', 'let']

# %% [markdown]
# ### The TFIDF-weighted features are very similar to the non-weighted one, let's only print them if they aren't in the top 20 overall words!

# %%
# tfidf now...
n=20
for i in range(len(decades)):
    decade_words = []
    vocab = all3_vec.get_feature_names()
    print str(decades[i])+'\'s'
    dist = tfidf_all3[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    top_50 = sorted_count_dict[:50]
    top_50 = [str(i[0]) for i in top_50]
    for word in top_50:
        if word not in top_20_overall:
            decade_words.append(word)
    print decade_words
# Out:
# 1950's
# ['well', 'little', 'gonna', 'heart', 'pretty', 'la', 'said', 'true', 'oh oh', 'na', 'tell', 'day', 'da', 'night', 'na na', 'la la', 'na na na', 'ooh', 'cha', 'right', 'long', 'la la la', 'take', 'cha cha', 'home', 'every', 'around', 'ah', 'hey', 'man', 'mine']
# 1960's
# ['little', 'heart', 'tell', 'gonna', 'day', 'man', 'cause', 'good', 'away', 'well', 'night', 'hey', 'right', 'la', 'said', 'take', 'every', 'world', 'back', 'long', 'around', 'look', 'could', 'need', 'wanna', 'yeah yeah', 'la la', 'home', 'life', 'eyes']
# 1970's
# ['gonna', 'man', 'day', 'night', 'right', 'feel', 'cause', 'take', 'good', 'away', 'well', 'life', 'ooh', 'said', 'back', 'need', 'tell', 'little', 'hey', 'long', 'heart', 'wanna', 'could', 'around', 'world', 'keep', 'home', 'think', 'people', 'mind']
# 1980's
# ['night', 'heart', 'feel', 'gonna', 'take', 'right', 'tell', 'away', 'could', 'cause', 'need', 'back', 'day', 'wanna', 'well', 'eyes', 'life', 'ooh', 'give', 'little', 'think', 'good', 'said', 'look', 'world', 'man', 'long', 'keep', 'tonight', 'around']
# 1990's
# ['cause', 'wanna', 'man', 'feel', 'right', 'back', 'need', 'take', 'heart', 'give', 'tell', 'gonna', 'could', 'night', 'good', 'ya', 'life', 'yo', 'think', 'day', 'world', 'little', 'around', 'would', 'every', 'mind', 'keep', 'ooh', 'hey', 'said']
# 2000's
# ['wanna', 'cause', 'back', 'ya', 'right', 'take', 'tell', 'man', 'gonna', 'need', 'think', 'feel', 'hey', 'could', 'little', 'la', 'give', 'nigga', 'life', 'said', 'uh', 'night', 'keep', 'around', 'good', 'boy', 'look', 'put', 'gotta', 'day']
# 2010's
# ['cause', 'wanna', 'back', 'oh oh', 'right', 'take', 'nigga', 'need', 'gonna', 'night', 'tell', 'feel', 'hey', 'little', 'good', 'shit', 'could', 'man', 'oh oh oh', 'bitch', 'think', 'life', 'money', 'give', 'niggas', 'la', 'na', 'keep', 'fuck', 'look']

# %% [markdown]
# ## TFIDF Bigrams Only:

# %%
# tfidf now...
n=20
for i in range(len(decades)):
    vocab = bigram_vec.get_feature_names()
    print str(decades[i])+'\'s'
    dist = tfidf_bigram[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    print n, ' most frequent features:'
    print sorted_count_dict[:n]
# Out:
# 1950's
# 20  most frequent features:
# [(u'oh oh', 0.33849451252439555), (u'na na', 0.30088401113279606), (u'la la', 0.29551108236256757), (u'cha cha', 0.24907046594341081), (u'dooby doom', 0.23078501328771181), (u'doom dooby', 0.20514223403352161), (u'da da', 0.20417129326868302), (u'yeah yeah', 0.19879836449845453), (u'love love', 0.15581493433662652), (u'pretty girl', 0.14506907679616951), (u'ooh ooh', 0.13969614802594102), (u'hula hoop', 0.13645738797992701), (u'bom bom', 0.12357736171525552), (u'hey hey', 0.11820443294502701), (u'really mine', 0.10916591038394161), (u'ah ah', 0.10745857540457002), (u'girl pretty', 0.10353651833362108), (u'kansas city', 0.1000687511852798), (u'pretty pretty', 0.097446134902231613), (u'pretty baby', 0.08994211270178723)]
# 1960's
# 20  most frequent features:
# [(u'yeah yeah', 0.34852961921152398), (u'la la', 0.3339671003029645), (u'oh oh', 0.28348370141995827), (u'oop oop', 0.19615187147095514), (u'love love', 0.15727520421244259), (u'oh yeah', 0.14950852746121085), (u'batman batman', 0.14131852413780241), (u'hey hey', 0.13494600855265135), (u'little girl', 0.11747098586237996), (u'da da', 0.10096679776601253), (u'bird bird', 0.099998993298918315), (u'ba ba', 0.099025128578204585), (u'ah ah', 0.098054293984300628), (u'ooh ooh', 0.096112624796492685), (u'baby baby', 0.088345948045260955), (u'every day', 0.082520940481837154), (u'little bit', 0.07923394722499387), (u'alley oop', 0.078767701978447263), (u'last night', 0.076695932918413354), (u'let go', 0.076695932918413354)]
# 1970's
# 20  most frequent features:
# [(u'la la', 0.28478481176342735), (u'yeah yeah', 0.23208840958673016), (u'doo doo', 0.2197552090772904), (u'oh oh', 0.21302800879941416), (u'ooh ooh', 0.19060400787316004), (u'love love', 0.18836160778053462), (u'get get', 0.14742619218927244), (u'hey hey', 0.13454400555752472), (u'oh yeah', 0.13230160546489933), (u'oh baby', 0.1087564044923325), (u'baby baby', 0.10651400439970708), (u'rock roll', 0.10427160430708167), (u'ah ah', 0.095302003936580018), (u'love baby', 0.091938403797641899), (u'feel like', 0.086332403566078367), (u'let go', 0.086332403566078367), (u'every day', 0.08521120351976566), (u'come come', 0.080726403334514835), (u'na na', 0.073999203056638596), (u'make feel', 0.06951440287138777)]
# 1980's
# 20  most frequent features:
# [(u'oh oh', 0.39191088437156407), (u'yeah yeah', 0.26168344316972775), (u'let go', 0.19288404027064437), (u'ooh ooh', 0.19165547950458933), (u'love love', 0.13514168426605658), (u'na na', 0.13391312350000151), (u'oh yeah', 0.098284861284404779), (u'oh baby', 0.094599178986239596), (u'know love', 0.092142057454129483), (u'every time', 0.083542132091744062), (u'baby baby', 0.079856449793578879), (u'little bit', 0.079378895176003786), (u'look eyes', 0.079378895176003786), (u'feel like', 0.07617076749541371), (u'love like', 0.073713645963303584), (u'one thing', 0.071256524431193471), (u'gonna get', 0.066342281366973233), (u'every day', 0.066342281366973233), (u'make feel', 0.063885159834863106), (u'hey hey', 0.06265659906880805)]
# 1990's
# 20  most frequent features:
# [(u'oh oh', 0.3239775002162224), (u'yeah yeah', 0.24526465685383037), (u'la la', 0.14145496488313938), (u'let go', 0.1403141990373076), (u'da da', 0.12776577473315814), (u'oh yeah', 0.12662500888732636), (u'baby baby', 0.12092117965816752), (u'ooh ooh', 0.12092117965816752), (u'na na', 0.11978041381233576), (u'get get', 0.10861988742227084), (u'know know', 0.10038739443319568), (u'uh huh', 0.096965096895700376), (u'love love', 0.092402033512373305), (u'let know', 0.08327590674571915), (u'man whatta', 0.08166609315799539), (u'come come', 0.078712843362392065), (u'hey hey', 0.077572077516560298), (u'oh baby', 0.07643131167072853), (u'every day', 0.075290545824896762), (u'know love', 0.074149779979064995)]
# 2000's
# 20  most frequent features:
# [(u'la la', 0.34229261308434444), (u'oh oh', 0.33483345202439502), (u'na na', 0.24366592795834688), (u'yeah yeah', 0.20802771400525533), (u'let go', 0.17321829572549149), (u'da da', 0.15001201687231561), (u'hey hey', 0.11768898561253488), (u'get get', 0.11273590965460062), (u'uh uh', 0.11188741589924091), (u'love love', 0.10525705051261923), (u'ha ha', 0.1035994591659638), (u'wee ooh', 0.098502162869824758), (u'soulja boy', 0.096860460155327691), (u'let get', 0.091996319739375859), (u'uh huh', 0.087852341372737314), (u'flip flip', 0.081087768113081618), (u'every time', 0.079564384639460209), (u'little bit', 0.078915136758220442), (u'feel like', 0.077906793292804782), (u'oh yeah', 0.071276427906183104)]
# 2010's
# 20  most frequent features:
# [(u'oh oh', 0.58777973157961738), (u'na na', 0.25275519654772755), (u'la la', 0.22896647216676497), (u'yeah yeah', 0.18832740134928719), (u'let go', 0.14967072423022298), (u'hey hey', 0.13381157464291457), (u'clique clique', 0.1135337976970526), (u'imma imma', 0.10880322279300873), (u'work work', 0.10673751076040744), (u'know know', 0.10308447231750457), (u'feel like', 0.10110207861909103), (u'love love', 0.094163700674643594), (u'oh yeah', 0.078304551087335209), (u'girls run', 0.078054485916723662), (u'like like', 0.062445401500026809), (u'ass ass', 0.058901751432054963), (u'eh eh', 0.057301189987166101), (u'racks racks', 0.056766898848526301), (u'ooh ooh', 0.056498220404786158), (u'bad bitches', 0.054974968003251294)]

# %%
## again tfidf doesn't change the order much, so let's exclude top 20 again
n=20
for i in range(len(decades)):
    decade_words = []
    vocab = bigram_vec.get_feature_names()
    print str(decades[i])+'\'s'
    dist = tfidf_bigram[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    top_50 = sorted_count_dict[:50]
    top_50 = [str(i[0]) for i in top_50]
    for word in top_50:
        if word not in top_20_overall_bigram:
            decade_words.append(word)
    print decade_words
# Out:
# 1950's
# ['cha cha', 'dooby doom', 'doom dooby', 'pretty girl', 'hula hoop', 'bom bom', 'really mine', 'girl pretty', 'kansas city', 'pretty pretty', 'pretty baby', 'yi yi', 'come home', 'burn burn', 'bye bye', 'baby bye', 'love true', 'rock roll', 'never gonna', 'high school', 'little girl', 'gonna tell', 'new pair', 'doo wah', 'la da', 'pretty little', 'true love', 'mine mine', 'love oh', 'last night', 'bah bah', 'goodbye baby', 'dooby dooby', 'uh huh', 'see baby']
# 1960's
# ['oop oop', 'batman batman', 'little girl', 'bird bird', 'ba ba', 'little bit', 'alley oop', 'last night', 'ha ha', 'dee dum', 'come back', 'yeah oh', 'long time', 'dum dum', 'come baby', 'oom mow', 'dum dee', 'hitch hike', 'um um', 'monkey monkey', 'love like', 'baby love', 'oh yes', 'come come', 'true love', 'never never', 'love oh', 'one day', 'dah dah', 'hold tight', 'well bird', 'papa oom']
# 1970's
# ['rock roll', 'love baby', 'come come', 'make feel', 'let know', 'baby love', 'chh chh', 'know got', 'aah aah', 'come back', 'little bit', 'uh huh', 'baby let', 'nah nah', 'gimme dat', 'oo oo', 'oh yes', 'de de', 'ghetto ghetto', 'got love', 'well well', 'baby know', 'make love', 'come home', 'long time', 'oh mammy', 'day day', 'dancing dancing', 'whoa whoa', 'good time']
# 1980's
# ['little bit', 'look eyes', 'love like', 'one thing', 'gonna get', 'make feel', 'square biz', 'love shack', 'set free', 'want love', 'say love', 'make love', 'one one', 'let know', 'love baby', 'day day', 'lay hands', 'whoa whoa', 'walk away', 'rock roll', 'close eyes', 'know got', 'one day', 'far away', 'baby love', 'never thought', 'ha ha', 'someone else', 'hot hot', 'gonna make', 'deserves encore', 'valley girl', 'need love']
# 1990's
# ['uh huh', 'let know', 'man whatta', 'come come', 'gangsta bitch', 'check check', 'world around', 'make love', 'around world', 'bump yo', 'whatta man', 'yes yes', 'love like', 'never knew', 'ya ya', 'wanna get', 'one two', 'give love', 'zoom zoom', 'gonna get', 'little bit', 'like like', 'wants give', 'verse one', 'one thing', 'boom boom', 'want know', 'look eyes', 'know got', 'know want']
# 2000's
# ['uh uh', 'ha ha', 'wee ooh', 'soulja boy', 'let get', 'uh huh', 'flip flip', 'little bit', 'swagger like', 'like like', 'wanna know', 'let see', 'like way', 'uh oh', 'go dumb', 'know got', 'go go', 'oh uh', 'dumb go', 'need girl', 'da ba', 'ooh wee', 'ay ay', 'feels like', 'crank dat', 'boom boom', 'like us', 'let know', 'us swagger', 'thoia thoia', 'lookin ass', 'go get', 'ass nigga', 'get back', 'dat soulja', 'bay bay', 'baby girl']
# 2010's
# ['clique clique', 'imma imma', 'work work', 'girls run', 'like like', 'ass ass', 'eh eh', 'racks racks', 'bad bitches', 'bubble bubble', 'bubble butt', 'go hard', 'chick bad', 'bring back', 'wanna see', 'whip hair', 'hold hold', 'little bit', 'got got', 'dumb dumb', 'hit quan', 'want want', 'friends new', 'bad bitch', 'hard go', 'love like', 'tell em', 'feels like', 'butt bubble', 'forth whip', 'know got', 'sh sh', 'rock right', 'looking like', 'feelin feelin', 'uh huh']

# %% [markdown]
# ## TFIDF Trigrams only:

# %%
# tfidf now...
n=20
for i in range(len(decades)):
    vocab = trigram_vec.get_feature_names()
    print str(decades[i])+'\'s'
    dist = tfidf_trigram[i] #one row of word features
    count_dict = dict(zip(vocab, dist))
    sorted_count_dict = sorted(count_dict.items(), key=operator.itemgetter(1),reverse=True)
    print n, ' most frequent features:'
    print sorted_count_dict[:n]
# Out:
# 1950's
# 20  most frequent features:
# [(u'na na na', 0.32703239893448227), (u'la la la', 0.3085211310702663), (u'dooby doom dooby', 0.23559111531497831), (u'da da da', 0.2097943691277811), (u'cha cha cha', 0.19955196024380795), (u'oh oh oh', 0.1851126786421598), (u'pretty girl pretty', 0.18333830447887453), (u'doom dooby doom', 0.14724444707186146), (u'yi ya yi', 0.14724444707186146), (u'la da dada', 0.14724444707186146), (u'bom bom bom', 0.13289298719534529), (u'tcha come home', 0.13252000236467532), (u'bom ba bom', 0.13252000236467532), (u'yeah yeah yeah', 0.12957887504951185), (u'girl pretty girl', 0.12536920397154883), (u'oh yi yi', 0.11779555765748916), (u'yi yi ya', 0.11779555765748916), (u'wow oh yi', 0.11779555765748916), (u'really mine really', 0.11779555765748916), (u'ooh ooh ooh', 0.1172380298067012)]
# 1960's
# 20  most frequent features:
# [(u'la la la', 0.42724631308640182), (u'yeah yeah yeah', 0.32122593169088731), (u'oop oop oop', 0.28698035387880794), (u'oh oh oh', 0.21995273155188835), (u'batman batman batman', 0.21523526540910598), (u'ba ba ba', 0.15282150496735564), (u'bird bird bird', 0.12460989050000873), (u'ah ah ah', 0.12184431891723312), (u'da da da', 0.12026192516506126), (u'ooh ooh ooh', 0.099690806386827091), (u'na na na', 0.099690806386827091), (u'hey hey hey', 0.094943625130311515), (u'alley oop oop', 0.094401432196976318), (u'oom mow mow', 0.086849317621218197), (u'doo doo doo', 0.085449262617280364), (u'love love love', 0.080702081360764788), (u'dum dee dum', 0.079297203045460105), (u'papa oom mow', 0.075521145757581051), (u'fa fa fa', 0.07209239218395512), (u'um um um', 0.07209239218395512)]
# 1970's
# 20  most frequent features:
# [(u'la la la', 0.38364306928509301), (u'doo doo doo', 0.29600886564129003), (u'ooh ooh ooh', 0.2181117957356874), (u'yeah yeah yeah', 0.18111068753052614), (u'oh oh oh', 0.14216215257772483), (u'get get get', 0.13465563055048801), (u'aah aah aah', 0.098918403213414066), (u'nah nah nah', 0.094469904761796855), (u'oo oo oo', 0.092783660882920088), (u'love love love', 0.091529057139083103), (u'na na na', 0.091529057139083103), (u'ah ah ah', 0.087634203643802977), (u'ghetto ghetto ghetto', 0.084865437136104407), (u'hey hey hey', 0.081791923400882774), (u'high high high', 0.079134722570731258), (u'de de de', 0.074354135465400609), (u'little hell raise', 0.074354135465400609), (u'hell raise little', 0.074354135465400609), (u'raise little hell', 0.07329287752663563), (u'come come come', 0.070639019305174036)]
# 1980's
# 20  most frequent features:
# [(u'oh oh oh', 0.41065893462150949), (u'yeah yeah yeah', 0.30476575022225233), (u'na na na', 0.24019673534465649), (u'ooh ooh ooh', 0.21436912939361816), (u'jump jump jump', 0.092088139325537652), (u'hot hot hot', 0.091832870212889023), (u'boom boom acka', 0.086285178619065026), (u'shake love shake', 0.080121951574846098), (u'love love love', 0.077482817853114991), (u'ba ba ba', 0.076492813862252276), (u'whoa whoa whoa', 0.076118645568778495), (u'ba ba bongo', 0.073958724530627171), (u'love shake love', 0.073958724530627171), (u'ba bongo bongo', 0.073958724530627171), (u'got love somebody', 0.071624108364307063), (u'ha ha ha', 0.069734536067803499), (u'doo doo doo', 0.069734536067803499), (u'hands lay hands', 0.067795497486408229), (u'must talking angel', 0.067795497486408229), (u'lay hands lay', 0.067795497486408229)]
# 1990's
# 20  most frequent features:
# [(u'oh oh oh', 0.33991114694765701), (u'yeah yeah yeah', 0.18092044918181746), (u'la la la', 0.17909296989715262), (u'around world around', 0.15565675033249207), (u'world around world', 0.15565675033249207), (u'na na na', 0.15168078062718029), (u'ooh ooh ooh', 0.13888842563452652), (u'da da da', 0.11695867421854865), (u'yes yes yes', 0.11583758164278479), (u'whatta man whatta', 0.10466168428941788), (u'bump yo body', 0.10466168428941788), (u'wanna bump yo', 0.10466168428941788), (u'check check check', 0.10210831614594437), (u'man whatta man', 0.095939877265299719), (u'handle handle handle', 0.087218070241181569), (u'baby baby baby', 0.082236567809917019), (u'ya ya ya', 0.077905634244032018), (u'snoop doggy dogg', 0.065413552680886167), (u'zoom zoom zoom', 0.065158639674066446), (u'dat dat dat', 0.064978019365600964)]
# 2000's
# 20  most frequent features:
# [(u'la la la', 0.45845194157961394), (u'na na na', 0.31348200329633064), (u'oh oh oh', 0.28126646145560097), (u'da da da', 0.16231676850521468), (u'wee ooh wee', 0.14726189464555495), (u'yeah yeah yeah', 0.13505746387075113), (u'uh uh uh', 0.11292814354951557), (u'swagger like us', 0.10644336807916849), (u'ha ha ha', 0.10036380342688846), (u'flip flip flip', 0.094616327181483106), (u'hey hey hey', 0.092929447617489308), (u'get get get', 0.08286624432329516), (u'go dumb go', 0.082789286283797711), (u'dumb go dumb', 0.082789286283797711), (u'oh uh oh', 0.081818480756763484), (u'uh oh uh', 0.07853967714429598), (u'ooh wee ooh', 0.073630947322777474), (u'love love love', 0.073104498792424921), (u'lookin ass nigga', 0.07096224538611233), (u'like us swagger', 0.07096224538611233)]
# 2010's
# 20  most frequent features:
# [(u'oh oh oh', 0.5506006867827502), (u'na na na', 0.28939928281034044), (u'la la la', 0.25378090954137544), (u'work work work', 0.14398762942632148), (u'yeah yeah yeah', 0.14098939418965303), (u'imma imma imma', 0.13457687853299138), (u'clique clique clique', 0.12749388492599187), (u'hey hey hey', 0.11872791089654992), (u'ass ass ass', 0.092078916890994122), (u'hard go home', 0.088537420087494351), (u'eh eh eh', 0.082901968457579037), (u'dumb dumb dumb', 0.081454426480494793), (u'feelin feelin feelin', 0.081454426480494793), (u'go hard go', 0.073493662204017429), (u'home go hard', 0.070829936069995478), (u'go home go', 0.070829936069995478), (u'wicked wicked wicked', 0.067288439266495692), (u'hair back forth', 0.067288439266495692), (u'whip hair back', 0.067288439266495692), (u'know know know', 0.06381625210689558)]

# %% [markdown]
# ## Now let's make our BoW features for each song (instead of each decade).
#
# ## Then these features will go into our recommender!!

# %%
# We can use the CountVectorizers defined previously -- all3_vec, bigram_vec, and trigram_vec
# But when we run fit_transform, this time we will input the cleaned lyrics column of the dataframe,
# such that each song will have it's own feature vector.
bow_all3 = all3_vec.fit_transform(lyrics_df.lyrics_clean_no_stopwords)
#bow_bigram = bigram_vec.fit_transform(lyrics_df.lyrics_clean_no_stopwords).toarray()
#bow_trigram = trigram_vec.fit_transform(lyrics_df.lyrics_clean_no_stopwords).toarray()
# Numpy arrays are easy to work with, so convert the result to an array
# omit the "toarray()" above if you want to preserve sparse format
print('done!')
# Out:
# done!

# %%
bow_all3_array = bow_all3.toarray()

# %%
#that takes some time to run! probably because there are many songs!
print np.shape(bow_all3)
#print 'bow_all3 has ', np.shape(bow_all3)[0], ' songs , each with ', np.shape(bow_all3)[1], ' word:count features '
# Out:
# (15868, 5000)

# %%
bow_all3
# Out:
# <15868x5000 sparse matrix of type '<type 'numpy.int64'>'
# 	with 568360 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## To Do : FIgure out how to put the bag of words array into the database (lyrics_df)
# ## The for-loop below takes forever -- is there a better way?
# ## How big does the file become when we add 16,000 rows of 5000 numbers to it?
#
# --> The following cell takes maybe 30 minutes to run -- there must be a more efficient way to do this?

# %%
### ATTN! Only run this cell if you need to generate the dataframe with bag of words in it.
## If you don't need to generate it, read it from file (see next cell)
#lyrics_df["BoW_array"] = np.nan #add a row for the bag of words
## rather than run for all the rows, try just running for 10 rows. all rows takes forever!

#num_songs = len(lyrics_df)
#for i in range(num_songs):
#    if( (i+1)%500 == 0 ):
#        print("Song %d of %d\n" % ( i+1, num_songs )) 
#    lyrics_df['BoW_array'].iloc[i] = bow_all3[i][:]

# name_to_save = 'LyricsDF_with_BoW_sparse'
# lyrics_df.to_pickle(name_to_save)

# %%
#read the dataframe into new variable
lyrics_df_with_bow = pd.read_pickle('LyricsDF_with_BoW_sparse')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-43-bf86f048f8a4> in <module>()
#       1 #read the dataframe into new variable
# ----> 2 lyrics_df_with_bow = pd.read_pickle('LyricsDF_with_BoW_sparse')
#
# /Applications/anaconda/envs/py2/lib/python2.7/site-packages/pandas/io/pickle.pyc in read_pickle(path)
#      63
#      64     try:
# ---> 65         return try_read(path)
#      66     except:
#      67         if PY3:
#
# /Applications/anaconda/envs/py2/lib/python2.7/site-packages/pandas/io/pickle.pyc in try_read(path, encoding)
#      59             # compat pickle
#      60             except:
# ---> 61                 with open(path, 'rb') as fh:
#      62                     return pc.load(fh, encoding=encoding, compat=True)
#      63
#
# IOError: [Errno 2] No such file or directory: 'LyricsDF_with_BoW_sparse'

# %%
lyrics_df.BoW_array.head(11) #see the sparse format vectors are only in the top 10 rows

# %% [markdown]
# ## Cosine Similarity Between Bag-Of-Words Vectors -- Recommender

# %%
from scipy import spatial

#use this one if you're inputting sparse arrays that need to be converted
#def cos_sim(your_song_bow_vec, other_song_bow_vec):
#    your_song_bow_vec = your_song_bow_vec.toarray()
#    other_song_bow_vec = other_song_bow_vec.toarray()
#    result = 1 - spatial.distance.cosine(your_song_bow_vec, other_song_bow_vec)
#    return result

#use this one if your input vectors are already converted to arrays (from sparse)
def cos_sim(your_song_bow_vec, other_song_bow_vec):
    result = 1 - spatial.distance.cosine(your_song_bow_vec, other_song_bow_vec)
    return result

# %%
# test function
song1 = 'Bohemian Rhapsody'
song2 = 'Semi-Charmed Life'
bow1 = lyrics_df_with_bow[lyrics_df_with_bow['track_name']==song1].BoW_array.values[0].toarray()
bow2 = lyrics_df_with_bow[lyrics_df_with_bow['track_name']==song2].BoW_array.values[0].toarray()
print ' size bag of words vectors = ', np.shape(bow1), ' and ', np.shape(bow2)
similarity = cos_sim(bow1,bow2)
print 'similarity between ', song1, ' and ', song2 , ' = '
print similarity

# %%
bow1

# %% [markdown]
# ## In the absense of a better idea, we can iterate over all the rows and get a similarity between that row's song and the song of interest. This will take FOREVER to do on all 16,000 songs. Maybe what we should have is a 16,000x16,000 matrix that gives the similarity between any pair of songs, then the web app will query this matrix to find the most similar songs.

# %%
# get cosine similarities between our song "Lose Yourself" and all other songs, store in new column.
#recommend a song based on lexical density only
song_i_like = 'Lose Yourself'

#define similarity as diff between your song's lexical diversity & that of other songs
bow1 = lyrics_df_with_bow[lyrics_df_with_bow['track_name']==song_i_like].BoW_array.values[0].toarray()

#first subset for recent songs to recommend from..
recent = lyrics_df_with_bow[lyrics_df_with_bow['date']>datetime.date(2013,1,1)]
recent['cos_sim'] = np.nan #make empty column in the subset
how_deep = 100
print 'only looking at first ', how_deep, ' of the ', len(recent), 'recent songs'
#iterate over the rows. this is just for the first 10 rows, and it already takes a few seconds!
for i in range(how_deep):
    bow2 = recent.BoW_array.iloc[i].toarray()
    recent.cos_sim.iloc[i] = cos_sim(bow1,bow2)

#there must be a faster way if we use map or apply. 
# something like.. lyrics_df['cosine_sim'] = lyrics_df.apply(lambda x,y: cos_sim(x['BoW_array'],)) #map function 
# also there may be a fast way to use the sparse arrays instead of the expanded arrays.

#recommend 5 songs based on cosine similarity of lyrics (bag of words)
print 'You might like these recent tracks:'
recent.sort_values('cos_sim',ascending=False)[:5]

# %%
bow2 = lyrics_df.BoW_array.iloc[1].toarray()
bow2
